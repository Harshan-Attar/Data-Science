# %% [markdown]
# ## Market Basket Analysis using Apriori Algorithm on Store Dataset.

# %% [markdown]
# ### Harshan Attar

# %%
# unsupervised ML

# %%
pip install apyori
# Out:
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori

# %%
data = pd.read_csv(r"https://raw.githubusercontent.com/Harshan-Attar/Data-Science/main/Projects/Project%2011/apriori_data.csv")
data
# Out:
#     Unnamed: 0     A      B      C       D     E      F
# 0            1  Wine  Chips  Bread  Butter  Milk  Apple
# 1            2  Wine    NaN  Bread  Butter  Milk    NaN
# 2            3   NaN    NaN  Bread  Butter  Milk    NaN
# 3            4   NaN  Chips    NaN     NaN   NaN  Apple
# 4            5  Wine  Chips  Bread  Butter  Milk  Apple
# 5            6  Wine  Chips    NaN     NaN  Milk    NaN
# 6            7  Wine  Chips  Bread  Butter   NaN  Apple
# 7            8  Wine  Chips    NaN     NaN  Milk    NaN
# 8            9  Wine    NaN  Bread     NaN   NaN  Apple
# 9           10  Wine    NaN  Bread  Butter  Milk    NaN
# 10          11   NaN  Chips  Bread  Butter   NaN  Apple
# 11          12  Wine    NaN    NaN  Butter  Milk  Apple
# 12          13  Wine  Chips  Bread  Butter  Milk    NaN
# 13          14  Wine    NaN  Bread     NaN  Milk  Apple
# 14          15  Wine    NaN  Bread  Butter  Milk  Apple
# 15          16  Wine  Chips  Bread  Butter  Milk  Apple
# ...

# %%
records = []
for i in range(len(data)):
    records.append([str(data.values[i, j]) for j in range(len(data.columns))])

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)

# %%
association_results = list(association_rules)

# %%
# Print the association rules
for item in association_results:
    # Extract the rule, support, confidence, and lift
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])
    print("Support: " + str(item[1]))
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: Milk -> Chips
# Support: 0.045454545454545456
# Confidence: 1.0
# Lift: 3.142857142857143
# ...
# Rule: Wine -> Chips
# Support: 0.045454545454545456
# Confidence: 1.0
# Lift: 3.666666666666667
# ...
# Rule: Bread -> Chips
# Support: 0.045454545454545456
# Confidence: 1.0
# Lift: 3.142857142857143
# ...
# Rule: Bread -> Wine
# Support: 0.045454545454545456
# Confidence: 1.0
# Lift: 3.142857142857143
# ...
# Rule: Milk -> Butter
# Support: 0.045454545454545456
# Confidence: 1.0
# Lift: 3.142857142857143
# ...
# Rule: Wine -> Butter
# Support: 0.045454545454545456
# Confidence: 1.0
# Lift: 3.666666666666667
# ...
# Rule: Wine -> Butter
# Support: 0.045454545454545456
# Confidence: 1.0
# Lift: 3.142857142857143
# ...
# Rule: Butter -> Apple
# Support: 0.045454545454545456
# Confidence: 1.0
# Lift: 3.142857142857143
# ...
# Rule: Chips -> Apple
# Support: 0.045454545454545456
# Confidence: 1.0
# Lift: 3.666666666666667
# ...
# Rule: Bread -> Chips
# Support: 0.045454545454545456
# Confidence: 1.0
# Lift: 4.4
# ...
# Rule: Butter -> Chips
# ...
