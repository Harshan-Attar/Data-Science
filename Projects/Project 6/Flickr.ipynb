# %% [markdown]
# ## Flickr Image Scraper: Automating Image Collection

# %% [markdown]
# ### Harshan Attar

# %%
from bs4 import BeautifulSoup

# %%
pip install selenium
# Out:
# ...
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.9 MB 31.7 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.2/9.9 MB 25.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.2/9.9 MB 25.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.2/9.9 MB 25.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.2/9.9 MB 25.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.2/9.9 MB 25.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.2/9.9 MB 25.5 MB/s eta 0:00:01
#    ------ --------------------------------- 1.5/9.9 MB 4.1 MB/s eta 0:00:03
#    -------- ------------------------------- 2.0/9.9 MB 4.9 MB/s eta 0:00:02
# ...

# %%
import selenium
from selenium import webdriver

# %%
import time

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
site_script = 'https://www.flickr.com/search/?text='
def product():
    prod = input("Enter product name: ")
    return prod
site = site_script+product()
site
# Out:
# Enter product name:  cats
# 'https://www.flickr.com/search/?text=cats'

# %%
site
# Out:
# 'https://www.flickr.com/search/?text=tux'

# %%
driver = webdriver.Firefox()
driver.get(site)
driver.maximize_window()
time.sleep(10)

#Define an initial value
temp_height=0

while True:
    #Looping down the scroll bar
    driver.execute_script("window.scrollBy(0,1000)")
    #sleep and let the scroll bar react
    time.sleep(10)
    #Get the distance of the current scroll bar from the top
    check_height = driver.execute_script("return document.documentElement.scrollTop || window.pageYOffset || document.body.scrollTop;")
    #If the two are equal to the end
    if check_height==temp_height:
        break
    temp_height=check_height

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
all_div_tags = soup.find_all('div','view photo-list-photo-view awake')
len(all_div_tags)
# Out:
# 371

# %%
card = all_div_tags[0].find_all('img')[0]['src']
card
# Out:
# '//live.staticflickr.com/4182/33687599874_15e5167c80_m.jpg'

# %%
all_cards = ['https:'+i.find_all('img')[0]['src'] for i in all_div_tags]
all_cards
# Out:
# ['https://live.staticflickr.com/4182/33687599874_15e5167c80_m.jpg',
#  'https://live.staticflickr.com/4126/4957267113_fe7f8f0e3e_n.jpg',
#  'https://live.staticflickr.com/8782/17309607741_87eaca5855_n.jpg',
#  'https://live.staticflickr.com/2658/3708403335_7edce74672_m.jpg',
#  'https://live.staticflickr.com/1713/24438612999_1b0e2c7677_n.jpg',
#  'https://live.staticflickr.com/7435/13609396474_5a6a8d401d_m.jpg',
#  'https://live.staticflickr.com/806/39382175530_43288c08af_m.jpg',
#  'https://live.staticflickr.com/4561/26810102569_0b0396c318_n.jpg',
#  'https://live.staticflickr.com/4340/36430736285_5bc960fee3_n.jpg',
#  'https://live.staticflickr.com/961/41089865774_3beafca9df_n.jpg',
#  'https://live.staticflickr.com/8844/18410737290_841d82ec9f_n.jpg',
#  'https://live.staticflickr.com/1838/28135623287_0fff471c96_m.jpg',
#  'https://live.staticflickr.com/2293/32862691805_6efa2d6284_n.jpg',
#  'https://live.staticflickr.com/2895/33376108352_60f5fa3578_n.jpg',
# ...

# %%
# Better appraoch
images = all_div_tags[0].find('img')['src']
images
# Out:
# '//live.staticflickr.com/4182/33687599874_15e5167c80_m.jpg'

# %%
all_images = ['https:'+i.find('img')['src'] for i in all_div_tags]
all_images
# Out:
# ['https://live.staticflickr.com/4182/33687599874_15e5167c80_m.jpg',
#  'https://live.staticflickr.com/4126/4957267113_fe7f8f0e3e_n.jpg',
#  'https://live.staticflickr.com/8782/17309607741_87eaca5855_n.jpg',
#  'https://live.staticflickr.com/2658/3708403335_7edce74672_m.jpg',
#  'https://live.staticflickr.com/1713/24438612999_1b0e2c7677_n.jpg',
#  'https://live.staticflickr.com/7435/13609396474_5a6a8d401d_m.jpg',
#  'https://live.staticflickr.com/806/39382175530_43288c08af_m.jpg',
#  'https://live.staticflickr.com/4561/26810102569_0b0396c318_n.jpg',
#  'https://live.staticflickr.com/4340/36430736285_5bc960fee3_n.jpg',
#  'https://live.staticflickr.com/961/41089865774_3beafca9df_n.jpg',
#  'https://live.staticflickr.com/8844/18410737290_841d82ec9f_n.jpg',
#  'https://live.staticflickr.com/1838/28135623287_0fff471c96_m.jpg',
#  'https://live.staticflickr.com/2293/32862691805_6efa2d6284_n.jpg',
#  'https://live.staticflickr.com/2895/33376108352_60f5fa3578_n.jpg',
# ...

# %%
import urllib.request
pic = 1

for i in img_src:
    try:
        print(i)
        urllib.request.urlretrieve(i,'C:\\picss\\cat'+str(pic)+".jpg")
        pic += 1
    except Exception as e:
        print(str(e))
